# %%
import pandas as pd

# %%
df=pd.read_csv('csv.car.csv')

# %% [markdown]
# 1.From which manufacturing year to which manufacturing year vehicles are present in this data ?

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [markdown]
# 2..What is the lowest price to which a vehicle is sold ?

# %%
df['Selling_Price'].min()
# Out:
# 0.1

# %% [markdown]
# 3.What is the highest price to which a vehicle is sold ?

# %%
df['Selling_Price'].max()
# Out:
# 35.0

# %% [markdown]
# 4.How many records are there in this data ?

# %%
df.shape[0]
# Out:
# 301

# %% [markdown]
# 5.Are there any missing records in this data ?

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# 6.How many different vehicles are present in this data ?

# %%
df['Car_Name'].nunique()
# Out:
# 98

# %% [markdown]
# 7.Which is the most sold vehicle in this data ?

# %%
df['Car_Name'].mode()
# Out:
# 0    city
# Name: Car_Name, dtype: object

# %% [markdown]
# 8.Does the database include any CNG vehicle ? If yes how many of them are there ?

# %%
df['Fuel_Type'].unique()
df['Fuel_Type'].nunique()
# Out:
# 3

# %% [markdown]
# 9.How many vehicles here are for sell from Individuals directly ?

# %%
df['Seller_Type'].value_counts()
# Out:
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64

# %% [markdown]
# 10.Does this database contain auto transmission vehicles ? If yes how many of them are there ?

# %%
df['Transmission'].unique()
df['Transmission'].value_counts()
# Out:
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %% [markdown]
# 11.How many single person owned vehicles are there in this database ?

# %%
df['Owner'].value_counts()
# Out:
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %% [markdown]
# 12.Which is the most and least cost depreciated vehicle in data ?

# %%
df['Depreciation']=df['Present_Price']-df['Selling_Price']
min_depreciation = df['Depreciation'].min()
df[df['Depreciation'] == min_depreciation]
# Out:
#             Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 155  Honda Activa 4G  2017           0.48           0.51        4300
#
#     Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 155    Petrol  Individual    Automatic      0          0.03

# %%
max_depreciation = df['Depreciation'].max()
df[df['Depreciation'] == max_depreciation]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 86  land cruiser  2010           35.0           92.6       78000    Diesel
#
#    Seller_Type Transmission  Owner  Depreciation
# 86      Dealer       Manual      0          57.6

# %% [markdown]
# 13.Which brands of vehicles are less affected by cost depreciation?

# %%
min_depreciation = df['Depreciation'].min()
df[df['Depreciation'] == min_depreciation]
# Out:
#             Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 155  Honda Activa 4G  2017           0.48           0.51        4300
#
#     Fuel_Type Seller_Type Transmission  Owner  Depreciation
# 155    Petrol  Individual    Automatic      0          0.03

# %% [markdown]
# 14.14.Are there any factors which you feel affect the cost depreciation

# %%
df['Depreciation']
# Out:
# 0      2.24
# 1      4.79
# 2      2.60
# 3      1.30
# 4      2.27
#        ...
# 296    2.10
# 297    1.90
# 298    7.65
# 299    1.00
# 300    0.60
# Name: Depreciation, Length: 301, dtype: float64

# %% [markdown]
# 15.In general selling price is affected by age of vehicle and distance driven by vehicle , is it observable from data ?
#
# ```
# # This is formatted as code
# ```

# %%
df['Age']=2024-df['Year']
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Depreciation  Age
# 0        Dealer       Manual      0          2.24   10
# 1        Dealer       Manual      0          4.79   11
# 2        Dealer       Manual      0          2.60    7
# 3        Dealer       Manual      0          1.30   13
# 4        Dealer       Manual      0          2.27   10
# ..          ...          ...    ...           ...  ...
# 296      Dealer       Manual      0          2.10    8
# 297      Dealer       Manual      0          1.90    9
# 298      Dealer       Manual      0          7.65   15
# 299      Dealer       Manual      0          1.00    7
# 300      Dealer       Manual      0          0.60    8
#
# [301 rows x 11 columns]

# %% [markdown]
# 16.Can we get idea about newest vehicles i.e. after 2014 manufactured ?

# %%
df[df['Year']>2014]
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 2             ciaz  2017           7.25           9.85        6900    Petrol
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# 6             ciaz  2015           6.75           8.12       18796    Petrol
# 7          s cross  2015           6.50           8.61       33429    Diesel
# 8             ciaz  2016           8.75           8.89       20273    Diesel
# ..             ...   ...            ...            ...         ...       ...
# 295           city  2015           8.55          13.09       60076    Diesel
# 296           city  2016           9.50          11.60       33988    Diesel
# 297           brio  2015           4.00           5.90       60000    Petrol
# 299           city  2017          11.50          12.50        9000    Diesel
# 300           brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Depreciation  Age
# 2        Dealer       Manual      0          2.60    7
# 5        Dealer       Manual      0          0.58    6
# 6        Dealer       Manual      0          1.37    9
# 7        Dealer       Manual      0          2.11    9
# 8        Dealer       Manual      0          0.14    8
# ..          ...          ...    ...           ...  ...
# 295      Dealer       Manual      0          4.54    9
# 296      Dealer       Manual      0          2.10    8
# 297      Dealer       Manual      0          1.90    9
# 299      Dealer       Manual      0          1.00    7
# 300      Dealer       Manual      0          0.60    8
#
# [147 rows x 11 columns]

# %% [markdown]
# 17.Can we find out data of only two wheelers from this data

# %%
two_wheeler=df[df['Present_Price']<3.5]
two_wheeler
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 23                    alto k10  2014           2.50           3.46
# 37                         800  2003           0.35           2.28
# 44                        omni  2012           1.25           2.69
# 100  Royal Enfield Thunder 500  2016           1.75           1.90
# 101         UM Renegade Mojave  2017           1.70           1.82
# ..                         ...   ...            ...            ...
# 196                  Activa 3g  2008           0.17           0.52
# 197           Honda CB twister  2010           0.16           0.51
# 198         Bajaj Discover 125  2011           0.15           0.57
# 199             Honda CB Shine  2007           0.12           0.58
# 200           Bajaj Pulsar 150  2006           0.10           0.75
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner  Depreciation  Age
# 23        45280    Petrol      Dealer       Manual      0          0.96   10
# 37       127000    Petrol  Individual       Manual      0          1.93   21
# 44        50000    Petrol      Dealer       Manual      0          1.44   12
# 100        3000    Petrol  Individual       Manual      0          0.15    8
# 101        1400    Petrol  Individual       Manual      0          0.12    7
# ..          ...       ...         ...          ...    ...           ...  ...
# 196      500000    Petrol  Individual    Automatic      0          0.35   16
# 197       33000    Petrol  Individual       Manual      0          0.35   14
# 198       35000    Petrol  Individual       Manual      1          0.42   13
# 199       53000    Petrol  Individual       Manual      0          0.46   17
# 200       92233    Petrol  Individual       Manual      0          0.65   18
#
# [104 rows x 11 columns]

# %%
two_wheeler=two_wheeler[two_wheeler['Car_Name'] != 'alto k10']
two_wheeler=two_wheeler[two_wheeler['Car_Name'] != '800']
two_wheeler=two_wheeler[two_wheeler['Car_Name'] != 'omni']
two_wheeler
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 100  Royal Enfield Thunder 500  2016           1.75           1.90
# 101         UM Renegade Mojave  2017           1.70           1.82
# 102                  KTM RC200  2017           1.65           1.78
# 103          Bajaj Dominar 400  2017           1.45           1.60
# 104  Royal Enfield Classic 350  2017           1.35           1.47
# ..                         ...   ...            ...            ...
# 196                  Activa 3g  2008           0.17           0.52
# 197           Honda CB twister  2010           0.16           0.51
# 198         Bajaj Discover 125  2011           0.15           0.57
# 199             Honda CB Shine  2007           0.12           0.58
# 200           Bajaj Pulsar 150  2006           0.10           0.75
#
#      Kms_Driven Fuel_Type Seller_Type Transmission  Owner  Depreciation  Age
# 100        3000    Petrol  Individual       Manual      0          0.15    8
# 101        1400    Petrol  Individual       Manual      0          0.12    7
# 102        4000    Petrol  Individual       Manual      0          0.13    7
# 103        1200    Petrol  Individual       Manual      0          0.15    7
# 104        4100    Petrol  Individual       Manual      0          0.12    7
# ..          ...       ...         ...          ...    ...           ...  ...
# 196      500000    Petrol  Individual    Automatic      0          0.35   16
# 197       33000    Petrol  Individual       Manual      0          0.35   14
# 198       35000    Petrol  Individual       Manual      1          0.42   13
# 199       53000    Petrol  Individual       Manual      0          0.46   17
# 200       92233    Petrol  Individual       Manual      0          0.65   18
#
# [101 rows x 11 columns]

# %%
two_wheeler.reset_index(drop=True,inplace=True)
two_wheeler.head()
# Out:
#                     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0  Royal Enfield Thunder 500  2016           1.75           1.90        3000
# 1         UM Renegade Mojave  2017           1.70           1.82        1400
# 2                  KTM RC200  2017           1.65           1.78        4000
# 3          Bajaj Dominar 400  2017           1.45           1.60        1200
# 4  Royal Enfield Classic 350  2017           1.35           1.47        4100
#
#   Fuel_Type Seller_Type Transmission  Owner  Depreciation  Age
# 0    Petrol  Individual       Manual      0          0.15    8
# 1    Petrol  Individual       Manual      0          0.12    7
# 2    Petrol  Individual       Manual      0          0.13    7
# 3    Petrol  Individual       Manual      0          0.15    7
# 4    Petrol  Individual       Manual      0          0.12    7

# %%
old=two_wheeler['Year'].min()
two_wheeler[two_wheeler['Year']==old]
# Out:
#                Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 89  Hero Super Splendor  2005            0.2           0.57       55000
#
#    Fuel_Type Seller_Type Transmission  Owner  Depreciation  Age
# 89    Petrol  Individual       Manual      0          0.37   19

# %% [markdown]
# 18.which is the newest bike sold here?

# %%
new=two_wheeler['Year'].max()
two_wheeler[two_wheeler['Year']==new]
# Out:
#                      Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 1          UM Renegade Mojave  2017           1.70           1.82        1400
# 2                   KTM RC200  2017           1.65           1.78        4000
# 3           Bajaj Dominar 400  2017           1.45           1.60        1200
# 4   Royal Enfield Classic 350  2017           1.35           1.47        4100
# 9   Royal Enfield Classic 350  2017           1.20           1.47       11000
# 26          Bajaj Avenger 220  2017           0.90           0.95        1300
# 28       Honda CB Hornet 160R  2017           0.80           0.87        3000
# 29          Yamaha FZ S V 2.0  2017           0.78           0.84        5000
# 30       Honda CB Hornet 160R  2017           0.75           0.87       11000
# 32          Bajaj Avenger 220  2017           0.75           0.95        3500
# 34         TVS Apache RTR 160  2017           0.65           0.81       11800
# 55            Honda Activa 4G  2017           0.48           0.51        4300
# 56                 TVS Sport   2017           0.48           0.52       15000
# 58          Honda Dream Yuga   2017           0.48           0.54        8600
# 59            Honda Activa 4G  2017           0.45           0.51        4000
# 73                  Activa 4g  2017           0.40           0.51        1300
#
#    Fuel_Type Seller_Type Transmission  Owner  Depreciation  Age
# 1     Petrol  Individual       Manual      0          0.12    7
# 2     Petrol  Individual       Manual      0          0.13    7
# 3     Petrol  Individual       Manual      0          0.15    7
# 4     Petrol  Individual       Manual      0          0.12    7
# 9     Petrol  Individual       Manual      0          0.27    7
# 26    Petrol  Individual       Manual      0          0.05    7
# 28    Petrol  Individual       Manual      0          0.07    7
# 29    Petrol  Individual       Manual      0          0.06    7
# 30    Petrol  Individual       Manual      0          0.12    7
# 32    Petrol  Individual       Manual      0          0.20    7
# 34    Petrol  Individual       Manual      0          0.16    7
# 55    Petrol  Individual    Automatic      0          0.03    7
# 56    Petrol  Individual       Manual      0          0.04    7
# 58    Petrol  Individual       Manual      0          0.06    7
# 59    Petrol  Individual    Automatic      0          0.06    7
# 73    Petrol  Individual    Automatic      0          0.11    7

# %% [markdown]
# 19.Which is the most sold bike here?

# %%
most_sold=two_wheeler['Selling_Price'].max()
two_wheeler[two_wheeler['Selling_Price']==most_sold]
# Out:
#                     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 0  Royal Enfield Thunder 500  2016           1.75            1.9        3000
#
#   Fuel_Type Seller_Type Transmission  Owner  Depreciation  Age
# 0    Petrol  Individual       Manual      0          0.15    8

# %% [markdown]
# 20.Do you find any deal in two wheelers which exceeded the general expectation ? Can you find reason for it>

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(two_wheeler.Selling_Price)
plt.show()

# %% [markdown]
# 21.Can we find out data of only cars from this data?

# %%
four_wheeler=df[df['Present_Price']>3.5]
four_wheeler
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  Depreciation  Age
# 0        Dealer       Manual      0          2.24   10
# 1        Dealer       Manual      0          4.79   11
# 2        Dealer       Manual      0          2.60    7
# 3        Dealer       Manual      0          1.30   13
# 4        Dealer       Manual      0          2.27   10
# ..          ...          ...    ...           ...  ...
# 296      Dealer       Manual      0          2.10    8
# 297      Dealer       Manual      0          1.90    9
# 298      Dealer       Manual      0          7.65   15
# 299      Dealer       Manual      0          1.00    7
# 300      Dealer       Manual      0          0.60    8
#
# [197 rows x 11 columns]

# %% [markdown]
# 22.Which is the oldest car sold here?

# %%
old=four_wheeler['Selling_Price'].min()
four_wheeler[four_wheeler['Selling_Price']==old]
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 47  wagon r  2006           1.05           4.15       65000    Petrol
#
#    Seller_Type Transmission  Owner  Depreciation  Age
# 47      Dealer       Manual      0           3.1   18

# %% [markdown]
# 23.Which is the newest car sold here?

# %%
new=four_wheeler['Selling_Price'].max()
four_wheeler[four_wheeler['Selling_Price']==new]
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 86  land cruiser  2010           35.0           92.6       78000    Diesel
#
#    Seller_Type Transmission  Owner  Depreciation  Age
# 86      Dealer       Manual      0          57.6   14

# %% [markdown]
# 24.Do you find any deal in cars which exceeded the general expectation ? Can you findreasonforit?

# %%
plt.boxplot(four_wheeler.Selling_Price)
plt.show()

# %%
df.Fuel_Type.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
plt.pie(df.Seller_Type.value_counts() , labels = ["Dealer","Individual"] , shadow = True)
plt.show()

# %% [markdown]
# what is the average selling price of vehicles by brand?

# %%
df.groupby('Car_Name')['Selling_Price'].mean()
# Out:
# Car_Name
# 800                  0.350000
# Activa 3g            0.310000
# Activa 4g            0.400000
# Bajaj  ct 100        0.180000
# Bajaj Avenger 150    0.750000
#                        ...
# sx4                  3.158333
# verna                6.107857
# vitara brezza        9.250000
# wagon r              2.512500
# xcent                4.966667
# Name: Selling_Price, Length: 98, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(df.Selling_Price,df.Age)
plt.xlabel='Selling Price'
plt.ylabel='Age'
plt.title='Selling Price vs Age'
plt.show()
